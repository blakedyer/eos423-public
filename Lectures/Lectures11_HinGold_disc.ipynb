# %% [markdown]
# Lecture 11: Discussion of Hinnov and Goldhammer (1991)

# %%
nb_list = !jupyter notebook list
server = [l for l in nb_list if 'eos423' in l][0].split(' :: ')[0]
prefix = server.split('?')[0]
token = server.split('?')[1]
notebook = 'Lectures11_HinGold_disc.ipynb'
url = prefix+'notebooks/'+notebook+'?'+token
# !decktape -s '1920x1080' rise $url pdf_slides/Lectures11_HinGold_disc.pdf
# Out:
# Loading page http://localhost:8889/notebooks/Lectures11_HinGold_disc.ipynb?token=52241e072fac7a0abdd2b9b83f9b3c611bd0c5fa62c898f7 ...
# actions jupyter-notebook:find-and-replace does not exist, still binding it in case it will be defined later...
# load_extensions {
#   '0': 'nbextensions_configurator/config_menu/main',
#   '1': 'contrib_nbextensions_help_item/main',
#   '2': 'rise/main',
#   '3': 'jupyter-js-widgets/extension',
#   '4': 'jupyter-black-master/jupyter-black',
#   '5': 'toc2/main',
#   '6': 'hide_code/hide_code',
#   '7': 'hide_input/main',
#   '8': 'codefolding/main',
#   '9': 'splitcell/splitcell'
# }
# Loaded moment locale en-gb
# Failed to load resource: the server responded with a status of 404 (Not Found)
# Loading extension: nbextensions_configurator/config_menu/main
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'background: url(images/cycles_intro/Elatina_big.jpg) 50% 50% no-repeat;\n' +
#     '  width: 100vw;\n' +
#     '  height: 30vh; background-size: 100%;',
#   newValue: 'background: url("images/cycles_intro/Elatina_big.jpg") 50% 50% no-repeat ; width: 100vw ; height: 30vh ; background-size: 100%'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:red',
#   newValue: 'color: red'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:red',
#   newValue: 'color: red'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'font-size:25px',
#   newValue: 'font-size: 25px'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'width:70wh;',
#   newValue: 'width: 70wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:100wh',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:red',
#   newValue: 'color: red'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'width:100wh;',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:100wh',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:20vh;',
#   newValue: 'height: 20vh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'width:100wh;',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:100wh',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:70vh;',
#   newValue: 'height: 70vh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'height:70vh',
#   newValue: 'height: 70vh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'width:100wh;',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:100wh',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'width:100wh;',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:100wh',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:80vh',
#   newValue: 'width: 80vh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'width:100wh;',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:100wh',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'width:100wh;',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:100wh',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:blue',
#   newValue: 'color: blue'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'width:100wh;',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:100wh',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:red',
#   newValue: 'color: red'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'width:100wh;',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:100wh',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:red',
#   newValue: 'color: red'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'width:100wh;',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer img.style changed {
#   change: 'changed',
#   tagName: 'img',
#   attribName: 'style',
#   oldValue: 'width:100wh',
#   newValue: 'width: 100wh'
# }
# HTML Sanitizer div.style changed {
#   change: 'changed',
#   tagName: 'div',
#   attribName: 'style',
#   oldValue: 'height:20vh;',
#   newValue: 'height: 20vh'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:red',
#   newValue: 'color: red'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:black',
#   newValue: 'color: black'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:black',
#   newValue: 'color: black'
# }
# HTML Sanitizer span.style changed {
#   change: 'changed',
#   tagName: 'span',
#   attribName: 'style',
#   oldValue: 'color:black',
#   newValue: 'color: black'
# }
# Loading extension: contrib_nbextensions_help_item/main
# Session: kernel_created (be9ac0d7-52c8-4c8d-a2bf-986ce1fe9569)
# Starting WebSockets: ws://localhost:8889/api/kernels/ddfbe2be-bad4-4891-b54c-ae5a3ae95f2e
# Failed to load extension: [ 'nbextensions/hide_code/hide_code' ] {
#   requireType: 'scripterror',
#   requireModules: [ 'nbextensions/hide_code/hide_code' ],
#   originalError: { isTrusted: true }
# }
# Loading extension: rise/main
# Loading extension: jupyter-js-widgets/extension
# Loading extension: hide_input/main
# Loading extension: splitcell/splitcell
# Kernel: kernel_connected (ddfbe2be-bad4-4891-b54c-ae5a3ae95f2e)
# Failed to load resource: the server responded with a status of 404 (Not Found)
# Loading extension: jupyter-black-master/jupyter-black
# Loading extension: toc2/main
# [toc2] Notebook fully loaded -- toc2 initialized
# Widgets are not available.  Please install widgetsnbextension or ipywidgets 4.0
# Loading extension: codefolding/main
# Loading page finished with status: 200
# RISE plugin activated
# Refused to apply style from 'http://localhost:8889/notebooks/Lectures11_HinGold_disc.css' because its MIME type ('text/html') is not a supported stylesheet MIME type, and strict MIME checking is enabled.
# Failed to load resource: the server responded with a status of 404 (Not Found)
# Failed to get file HinGold_disc.json. ReadyState: 4, Status: 404
# Codefolding: Wait for 1000 ms
# Printing slide #/slide-12-0 (13/13) ...
# Printed 13 slides

# %% [markdown]
# <center><div style="background: url(images/cycles_intro/Elatina_big.jpg) 50% 50% no-repeat;
#   width: 100vw;
#   height: 30vh; background-size: 100%;">
# </div></center>

# %% [markdown]
# # Lecture 11: Discussion of Hinnov and Goldhammer (1991)
#
# 1. <span style="color:red">Geological setting</span>
# 2. <span style="color:blue">Cycles in the Latemar Limestone (**space**)</span>
# 3. <span style="color:blue">Potential origin of the Latemar cycles (**time**)</span>
# 4. <span style="color:blue">Testing the hypothesis: the data</span>
# 5. <span style="color:red">Testing the hypothesis: the analysis</span>

# %% [markdown]
# <div style='font-size:25px'> <i>We acknowledge and respect the lək̓ʷəŋən peoples on whose traditional territory the university stands and the Songhees, Esquimalt and W̱SÁNE&#262; peoples whose historical relationships with the land continue to this day.</i></div>

# %%
import random
def pick_group(class_list):
    if len(class_list)>0:
        picked=random.sample(class_list,2)
        [class_list.remove(p) for p in picked]
        print(' and '.join(picked))
    else:
        picked=[]
    return class_list,picked

# %% [markdown]
# # <span style="color:blue">Geological setting</span>
# - why would a platformal setting be especially senstive to sea level changes?
#
# <center>
#     <div style='width:70wh;'>
# 	    <img src="images/latemar_geom.png" style='width:100wh'>
#     </div>
# </center>

# %% [markdown]
# class

# %% [markdown]
# # <span style="color:red">Geological setting</span>
#
# <center>
#     <div style='width:100wh;'>
# 	    <img src="images/latemar_map.png" style='width:100wh'>
#     </div>
# </center>
# <center>
#     <div style='height:20vh;'>
# 	    <p>
#     </div>
# </center>

# %% [markdown]
# # <span style="color:blue">An ideal cycles in the Latemar Limestone</span>
# - what do the authors think is happening to sea level during deposition?
# - "*The absence of features indicating peritidal deposition between the subtidal member and vadose cap is conspicuous throughout the formation.*"
#
# <center>
#     <div style='width:100wh;'>
# 	    <img src="images/latemar_ideal_cycle.png" style='width:100wh'>
#     </div>
# </center>

# %% [markdown]
# # <span style="color:blue">Holocene parasequence</span>
# - why do the authors discuss the Holocene?
# - given your own work on (para)sequences anything odd about this holocene data?
#
# <center>
#     <div style='height:70vh;'>
# 	    <img src="images/npi_holocene.png" style='height:70vh'>
#     </div>
# </center>

# %% [markdown]
# class

# %% [markdown]
# # <span style="color:blue">Nested cycles in the Latemar Limestone</span>
# - where is the *ideal Latemar cycle* on this plot?
# - what is happening to **cycle thickness** up section?
# - what do the authors think is happening to sea level?
#
# <center>
#     <div style='width:100wh;'>
# 	    <img src="images/latemar_cycles.png" style='width:100wh'>
#     </div>
# </center>

# %% [markdown]
# class

# %% [markdown]
# # <span style="color:blue">What is the propesed driver of cyclicity?</span>
# - what is driving an *ideal cycle*?
# - what is driving the *bundling of cycles* into groups of five?
#
# <center>
#     <div style='width:100wh;'>
# 	    <img src="images/EOP.png" style='width:100wh'>
#     </div>
# </center>

# %% [markdown]
# class

# %% [markdown]
# <center>
# 	    <img src="images/imbrie.png" style='width:80vh'>
# </center>

# %% [markdown]
# # <span style="color:blue">But then why are the bundles asymmetric (according to the authors)?</span>
#
# <center>
#     <div style='width:100wh;'>
# 	    <img src="images/ESL.png" style='width:100wh'>
#     </div>
# </center>

# %% [markdown]
# class

# %% [markdown]
# # <span style="color:blue">How then is time distributed in the Latemar succession?</span>
# - How long does one cycle last? How about 5 cycles?
#
# <center>
#     <div style='width:100wh;'>
# 	    <img src="images/latemar_cycles_time.png" style='width:100wh'>
#     </div>
# </center>

# %% [markdown]
# class

# %% [markdown]
# # <span style="color:blue">Testing the hypothesis: how are they going to do it?</span>
# <center>
#     <div style='width:100wh;'>
# 	    <img src="images/latemar_timeseries.png" style='width:100wh'>
#     </div>
# </center>

# %% [markdown]
# class

# %% [markdown]
# # <span style="color:red">Testing the hypothesis: the analysis</span>
# #### Authors need to accomplish two things:
# - show that a 5:1 bundling of cycles is a signicant feature of the data **(easier)**
#     - in other words, are there cycles in space?
# - make the case that 1 bundle = precession and 5 bundles = eccentricity **(way, way harder)**
#     - do the cycles require a **cyclic (in time)** forcing?
#
# <center>
#     <div style='width:100wh;'>
# 	    <img src="images/latemar_fft.png" style='width:100wh'>
#     </div>
# </center>

# %% [markdown]
# # <span style="color:red">Testing the hypothesis: the analysis</span>
#
# <center>
#     <div style='width:100wh;'>
# 	    <img src="images/latemar_smoothed_fft.png" style='width:100wh'>
#     </div>
# </center>
# <center>
#     <div style='height:20vh;'>
# 	    <p>
#     </div>
# </center>

# %% [markdown]
# # <span style="color:red">Overtones</span>

# %%
#make some white noise
N=500
t = np.arange(0.0, 500, 1)
meas=scipy.signal.sawtooth((2*np.pi*t)/50)
mf=fft(meas - np.mean(meas))
tf,power,results=fft_axes(mf,N,N,1)
#plot
fig1=plt.figure(1,figsize=(27,6))
ax1=fig1.add_subplot(121)
ax1.set_xlabel('time')
ax1.set_ylabel('signal')
ax1.plot(meas,'-',lw=1,color='#6495ED')
ax1=fig1.add_subplot(122)
ax1.plot(tf,power,'-',lw=1,color='#6495ED')
ax1.set_xlabel('frequency (cycles per unit time)')
_=ax1.set_ylabel('power')

# %% [markdown]
# # <span style="color:black">Noise: red or white?</span>
#
# Plotting help:

# %%
from scipy.fftpack import fft
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
import pandas as pd
import seaborn as sns
sns.set_context('talk')
# %matplotlib inline

def fft_axes(yf,T,N,dt):
    
    if N % 2==0:
        xf=np.hstack((np.arange(0,1/(2*dt),1/T),(N//2)/T))
        power=2.0/N *np.abs(yf[0:len(xf)])
    else:
        xf=np.arange(0,1/(2*dt),1/T)
        power=2.0/N *np.abs(yf[0:len(xf)])
        
    results=pd.DataFrame(zip(xf,power),columns=['freq','power'])
    results=results.sort_values(by=['power'],ascending=False)

    return xf,power,results

# %% [markdown]
# # <span style="color:black">Noise: red or white?</span>

# %%
#make some white noise
N=500
t = np.arange(0.0, 500, 1)
meas=np.random.uniform(size=500)
#periodic signal
amp=0.0 #amp=0.065 #amp=0.13
ang_freq=0.02
meas=meas + amp*np.sin(ang_freq* 2*np.pi*t)
#fft
mf=fft(meas - np.mean(meas))
tf,power,results=fft_axes(mf,N,N,1)
#plot
fig1=plt.figure(1,figsize=(27,6))
ax1=fig1.add_subplot(121)
ax1.set_xlabel('time')
ax1.set_ylabel('signal')
ax1.plot(meas,'-',lw=1,color='#6495ED')
ax1=fig1.add_subplot(122)
ax1.plot(tf,power,'-',lw=1,color='#6495ED')
# ax1.annotate('our signal',(ang_freq,power[tf==ang_freq][0]),xytext=(50, 0), textcoords='offset points',fontsize=16,arrowprops=dict(arrowstyle="->"))
ax1.set_xlabel('frequency (cycles per unit time)')
_=ax1.set_ylabel('power')

# %% [markdown]
# # <span style="color:black">Noise: red or white?</span>

# %%
#make some red noise
t = np.arange(0.0, 500, 1)
meas=np.random.randint(-1,2,500)
meas=np.cumsum(meas)
#periodic signal
amp=2 #amp=2
ang_freq=0.02
meas=meas + amp*np.sin(ang_freq * 2*np.pi*t)
#fft
mf=fft(meas - np.mean(meas))
tf,power,results=fft_axes(mf,N,N,1)
#plot
fig1=plt.figure(1,figsize=(27,6))
ax1=fig1.add_subplot(121)
ax1.set_xlabel('time')
ax1.plot(meas,'-',lw=1,color='#6495ED')
ax1=fig1.add_subplot(122)
# ax1.plot(tf,power,'-',lw=1,color='#6495ED')
ax1.plot(np.log10(tf[1:]),np.log10(power[1:]),'-',lw=1,color='#6495ED')
# ax1.annotate('our signal',(np.log10(ang_freq),np.log10(power[tf==ang_freq][0])),xytext=(50, 0), textcoords='offset points',fontsize=16,arrowprops=dict(arrowstyle="->"))
ax1.set_xlabel('frequency (cycles per unit time)')
_=ax1.set_ylabel('power')

# %%
#make some white noise
N=100
t = np.linspace(0.0, N, 100000)
meas=2*np.sin((2*np.pi*t)/50)+np.cos(2*np.pi*t/10)

#plot
fig1=plt.figure(1,figsize=(27,6))
plt.plot(t,meas+t/5)
